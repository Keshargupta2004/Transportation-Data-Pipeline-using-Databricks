# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
import pyspark.sql.functions as F

# %%
orders_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/transportation/default/raw_data/orders.csv")

display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>product_id</th><th>amount</th><th>order_date</th></tr></thead><tbody><tr><td>1</td><td>101</td><td>1001</td><td>500</td><td>2024-01-01</td></tr><tr><td>2</td><td>102</td><td>1002</td><td>300</td><td>2024-01-02</td></tr><tr><td>3</td><td>103</td><td>1003</td><td>700</td><td>2024-01-03</td></tr><tr><td>4</td><td>101</td><td>1002</td><td>200</td><td>2024-01-04</td></tr><tr><td>5</td><td>104</td><td>1001</td><td>900</td><td>2024-01-05</td></tr></tbody></table></div>

# %%
orders_df = spark.read.format("csv") \
    .option("header", True) \
    .option("inferSchema", True) \
    .load("/Volumes/transportation/default/raw_data/orders.csv")

display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>product_id</th><th>amount</th><th>order_date</th></tr></thead><tbody><tr><td>1</td><td>101</td><td>1001</td><td>500</td><td>2024-01-01</td></tr><tr><td>2</td><td>102</td><td>1002</td><td>300</td><td>2024-01-02</td></tr><tr><td>3</td><td>103</td><td>1003</td><td>700</td><td>2024-01-03</td></tr><tr><td>4</td><td>101</td><td>1002</td><td>200</td><td>2024-01-04</td></tr><tr><td>5</td><td>104</td><td>1001</td><td>900</td><td>2024-01-05</td></tr></tbody></table></div>

# %%
orders_df.write.mode("overwrite").saveAsTable("transportation.bronze.orders")
